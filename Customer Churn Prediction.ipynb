# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\9919i\Downloads\archive (19)\customer_churn_data.csv")

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4             NaN       2208.32          No   Yes

# %%
df.isna().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# MonthlyCharges       0
# ContractType         0
# InternetService    297
# TotalCharges         0
# TechSupport          0
# Churn                0
# dtype: int64

# %%
df["InternetService"]=df["InternetService"].fillna("")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         CustomerID          Age      Tenure  MonthlyCharges  TotalCharges
# count  1000.000000  1000.000000  1000.00000     1000.000000   1000.000000
# mean    500.500000    44.674000    18.97300       74.391290   1404.364060
# std     288.819436     9.797741    18.89257       25.712083   1571.755048
# min       1.000000    12.000000     0.00000       30.000000      0.000000
# 25%     250.750000    38.000000     5.00000       52.357500    345.217500
# 50%     500.500000    45.000000    13.00000       74.060000    872.870000
# 75%     750.250000    51.000000    26.00000       96.102500   1900.175000
# max    1000.000000    83.000000   122.00000      119.960000  12416.250000

# %%
numeric_cols_data=df.select_dtypes(include=["number"])

# %%
numeric_cols_data.corr()
# Out:
#                 CustomerID       Age    Tenure  MonthlyCharges  TotalCharges
# CustomerID        1.000000  0.036730 -0.018585       -0.030504     -0.027490
# Age               0.036730  1.000000  0.000472        0.006362     -0.001896
# Tenure           -0.018585  0.000472  1.000000       -0.014552      0.894868
# MonthlyCharges   -0.030504  0.006362 -0.014552        1.000000      0.304893
# TotalCharges     -0.027490 -0.001896  0.894868        0.304893      1.000000

# %%
df["Churn"].value_counts()
# Out:
# Churn
# Yes    883
# No     117
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df["Churn"].value_counts().plot(kind="pie")
plt.title("Churn(Yes/No)")
plt.ylabel("")
plt.show()

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     62.54641
# Yes    75.96077
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby(["Churn","Gender"])["MonthlyCharges"].mean()
# Out:
# Churn  Gender
# No     Female    65.091912
#        Male      59.013878
# Yes    Female    74.975064
#        Male      77.082518
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby("Churn")["Tenure"].mean()
# Out:
# Churn
# No     30.264957
# Yes    17.476784
# Name: Tenure, dtype: float64

# %%
df.groupby("Churn")["Age"].mean()
# Out:
# Churn
# No     43.487179
# Yes    44.831257
# Name: Age, dtype: float64

# %%
df.groupby("ContractType")["MonthlyCharges"].mean()
# Out:
# ContractType
# Month-to-Month    75.909198
# One-Year          73.822803
# Two-Year          71.334500
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby("ContractType")["MonthlyCharges"].mean().plot(kind="bar")
plt.ylabel("Mean Price")
plt.xlabel("Contract type")
plt.title("Contract typeAverage Price")
plt.show()

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
plt.hist(df["MonthlyCharges"])
plt.title("Histogram of Monthly Charges")
plt.show()

# %%
plt.hist(df["Tenure"])
plt.title("Histogram of Tenure")
plt.show()

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='object')

# %%
x=df[["Age","Gender","Tenure","MonthlyCharges"]]
y=df[["Churn"]]

# %%
x#1 female,0 male
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49    Male       4           88.35
# 1     43    Male       0           36.67
# 2     51  Female       2           63.79
# 3     60  Female       8          102.34
# 4     42    Male      32           69.01
# ..   ...     ...     ...             ...
# 995   42    Male      41           37.14
# 996   62    Male       9           80.93
# 997   51  Female      15          111.72
# 998   39    Male      68           65.67
# 999   50    Male       1           56.67
#
# [1000 rows x 4 columns]

# %%
x["Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
# 1 female,0 male
x["Gender"]=x["Gender"].apply(lambda x:1 if x=="Female" else 0)
# Out:
# C:\Users\9919i\AppData\Local\Temp\ipykernel_23828\3111906070.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["Gender"]=x["Gender"].apply(lambda x:1 if x=="Female" else 0)

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
x.head
# Out:
# <bound method NDFrame.head of      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]>

# %%
y
# Out:
#     Churn
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4     Yes
# ..    ...
# 995   Yes
# 996   Yes
# 997   Yes
# 998   Yes
# 999   Yes
#
# [1000 rows x 1 columns]

# %%
y.head()
# Out:
#   Churn
# 0   Yes
# 1   Yes
# 2   Yes
# 3   Yes
# 4   Yes

# %%
# 1 female,0 male
y["Churn"]=y["Churn"].apply(lambda x:1 if x=="Yes" else 0)
# Out:
# C:\Users\9919i\AppData\Local\Temp\ipykernel_23828\1243788421.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y["Churn"]=y["Churn"].apply(lambda x:1 if x=="Yes" else 0)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_tain,y_test=train_test_split(x,y,test_size=0.2)

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(x_train)

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
x_test=scaler.fit_transform(x_test)

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions):
    print("Accuracy score on model is {}".format(accuracy_score(y_test,predictions)))

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model=LogisticRegression()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
log_model.fit(x_train,y_tain)
# Out:
# LogisticRegression()

# %%
x
# Out:
#      Age  Gender  Tenure  MonthlyCharges
# 0     49       0       4           88.35
# 1     43       0       0           36.67
# 2     51       1       2           63.79
# 3     60       1       8          102.34
# 4     42       0      32           69.01
# ..   ...     ...     ...             ...
# 995   42       0      41           37.14
# 996   62       0       9           80.93
# 997   51       1      15          111.72
# 998   39       0      68           65.67
# 999   50       0       1           56.67
#
# [1000 rows x 4 columns]

# %%
#log_model.predict([[40,0,20,80]])

# %%
y_pred=log_model.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.88

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid={
    "n_neighbors":[3,5,7,9],
    "weights":["uniform","distance"],
}

# %%
gridkn=GridSearchCV(KNeighborsClassifier(),param_grid,cv=5)

# %%
gridkn.fit(x_train,y_tain)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'n_neighbors': 9, 'weights': 'uniform'}

# %%
y_pred=gridkn.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.88

# %%
from sklearn.svm import SVC

# %%
svm=SVC()

# %%
param_grid={
    "C":[0.01,0.1,0.5,1],
    "kernel":["linear","rbf","poly"]
}

# %%
gridsvc=GridSearchCV(svm,param_grid,cv=5)

# %%
gridsvc.fit(x_train,y_tain)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
gridsvc.best_params_
# Out:
# {'C': 0.01, 'kernel': 'linear'}

# %%
y_pred=gridsvc.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.88

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid={
    "criterion":["gini","entropy"],
    "splitter":["best","random"],
    "max_depth":[None,10,20,30],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,2,4]
}

# %%
grid_tree=GridSearchCV(DecisionTreeClassifier(),param_grid,cv=5)

# %%
grid_tree.fit(x_train,y_tain)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_tree.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
y_pred=grid_tree.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.88

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_model=RandomForestClassifier()

# %%
param_grid={
    "n_estimators":[32,64,128,256],
    "max_features":[2,3,4],
    "bootstrap":[True,False]
}

# %%
grid_rfc=GridSearchCV(rfc_model,param_grid,cv=5)

# %%
grid_rfc.fit(x_train,y_tain)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_features': [2, 3, 4],
#                          'n_estimators': [32, 64, 128, 256]})

# %%
grid_rfc.best_params_
# Out:
# {'bootstrap': True, 'max_features': 2, 'n_estimators': 128}

# %%
y_pred=grid_rfc.predict(x_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy score on model is 0.88

# %%
best_model=gridsvc.best_params_

# %%
joblib.dump(best_model,"model.pkl")
# Out:
# ['model.pkl']
